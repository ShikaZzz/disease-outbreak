# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
from IPython.display import Video,HTML

# %% [markdown]
# ## SARS Spreading Animation

# %%
# Video("sars_new.mp4")
HTML("""
<video width="740" height="350" controls>
<source src="sars_new.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="740" height="350" controls>
# <source src="sars_new.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Polio Spreading Animation

# %%
HTML("""
<video width="740" height="300" controls>
<source src="polio.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="740" height="300" controls>
# <source src="polio.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Ebola Spreading Animation

# %%
HTML("""
<video width="740" height="350" controls>
<source src="ebola.mp4" type="video/mp4">
</video>
""")
# Out:
# <video width="740" height="350" controls>
# <source src="ebola.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Diseases Comparison among infected Countries

# %%
fname = "country.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## Diseases Death Toll Globally

# %%
fname = "death.png"
plt.figure(figsize=(20,20))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## H1N1 Infection Timeline

# %%
fname = "timeline.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## US Population map

# %%
fname = "population distribution.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## H1N1 Infection Distribution

# %%
fname = "H1N1 distribution.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## H1N1 Infection Age Comparison

# %%
fname = "age group.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## Vaccined Percentage

# %%
fname = "figure1.png"
plt.figure(figsize=(20,20))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## Total Cases Each Disease Globally

# %%
fname = "case.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## US vs Mexico

# %%
fname = "h1n1_mex_us_death.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %%
fname = "h1n1_mex_us_case.png"
plt.figure(figsize=(18,18))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## Flights vs Cases

# %%
fname = "flights.png"
plt.figure(figsize=(20,20))
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# ## H1N1 Total Cases For All Countries

# %%
fname = "h1n1_top10_death.png"
plt.figure(figsize=(25,25))
plt.imshow(mpimg.imread(fname))

# %%
fname = "h1n1_top10.png"
plt.figure(figsize=(25,25))
plt.imshow(mpimg.imread(fname))
